# %%
import matplotlib.pyplot as plt

# %%
runtimeJ = [402, 201, 104, 55, 46, 28, 20,22]
nodes = [1,2,4,8,10,20,40,80]
efficiency = [1, 1, 402/416, 402/440, 402/460, 402/560, 402/800 , 402/1760 ]

# %%
plt.plot(nodes, efficiency, marker='o', linestyle='--', color='r', label='efficiency')

# %%
plt.xlabel('# of tasks')
plt.ylabel('efficienct score')
plt.title('Performance Analysis')
plt.legend()
plt.show()
