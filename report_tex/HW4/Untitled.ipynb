# %%
import matplotlib.pyplot as plt

# %%
time1 = [2404, 1533, 757, 462, 305, 243, 230]
time2 = [1654, 935, 530, 350, 210, 146, 111]
thread = [1, 2, 4, 8, 16, 32, 64]
speedup1 = [time1[0]/time1[i] for i in range(7)]
speedup2 = [time1[0]/time2[i] for i in range(7)]
perfect = thread

# %%
plt.plot(thread, thread, marker='v', linestyle='-', color='r', label='perfect')
plt.plot(thread, speedup, marker='o', linestyle='--', color='r', label='naive')
plt.plot(thread, speedup2, marker='^', linestyle='--', color='r', label='numa')
print(speedup2)
# Out:
# [1.4534461910519951, 2.5711229946524066, 4.535849056603774, 6.868571428571428, 11.447619047619048, 16.465753424657535, 21.087719298245613]

# %%
plt.xlabel('# of threads')
plt.ylabel('speedup')
plt.title('Naive Memory Speedup')
plt.legend()
plt.show()
